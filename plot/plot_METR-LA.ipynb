# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
import os



data_quantile_model = np.load('data/quantile_seed0.npz',allow_pickle=True)


print(data_quantile_model.files)

predeictions_quantile = data_quantile_model['prediction']
truths_quantile = data_quantile_model['truth']
print(predeictions_quantile.shape)
print(truths_quantile.shape)
#averaged_predictions_quantile = np.mean(predeictions_quantile, axis=-1)
#print(averaged_predictions_quantile.shape)
averaged_predeictions_quantile = predeictions_quantile[:,:,:,1]
down_predictions_quantile = predeictions_quantile[:,:,:,0]
up_predictions_quantile = predeictions_quantile[:,:,:,2]
print(averaged_predeictions_quantile.shape)
# Out:
# ['mis', 'width', 'mse', 'rmse', 'mae', 'prediction', 'truth']
# (12, 6912, 207, 3)
# (12, 6912, 207)
# (12, 6912, 207)

# %%
data_gpde_quantile_model = np.load('data/gpde_quantile_seed0.npz',allow_pickle=True)

print(data_gpde_quantile_model.files)

predeictions_gpde_quantile = data_gpde_quantile_model['prediction']
print(predeictions_gpde_quantile.shape)

averaged_predeictions_gpde_quantile = predeictions_gpde_quantile[:,:,:,1]
down_predictions_gpde_quantile = predeictions_gpde_quantile[:,:,:,0]
up_predictions_gpde_quantile = predeictions_gpde_quantile[:,:,:,2]
print(averaged_predeictions_gpde_quantile.shape)
# Out:
# ['mis', 'width', 'mse', 'rmse', 'mae', 'prediction', 'truth']
# (12, 6912, 207, 3)
# (12, 6912, 207)

# %%
data_gpde_quantile_phy_model = np.load('data/gpde_quantile_phy_seed0.npz',allow_pickle=True)

print(data_gpde_quantile_phy_model.files)

predeictions_gpde_quantile_phy = data_gpde_quantile_phy_model['prediction']
print(predeictions_gpde_quantile_phy.shape)

averaged_predeictions_gpde_quantile_phy = predeictions_gpde_quantile_phy[:,:,:,1]
down_predictions_gpde_quantile_phy = predeictions_gpde_quantile_phy[:,:,:,0]
up_predictions_gpde_quantile_phy = predeictions_gpde_quantile_phy[:,:,:,2]
print(averaged_predeictions_gpde_quantile_phy.shape)
# Out:
# ['mis', 'width', 'mse', 'rmse', 'mae', 'prediction', 'truth']
# (12, 6912, 207, 3)
# (12, 6912, 207)

# %%
# 5 min plot

num_days = 12 * 24 *2
start_time = 100
time_stamp = 0

for loc in range(207):
    location_folder = 'D:/uncertainty/EviDCRNN/plot/METR-LA/5min/Location_' + str(loc)
    if not os.path.exists(location_folder):
        os.makedirs(location_folder)
    
    for i in range(20):
        start_time = i * 24 * 12
        end_time = start_time + num_days

        result_quantile = averaged_predeictions_quantile[time_stamp,start_time:end_time,loc]
        result_down_quantile = down_predictions_quantile[time_stamp,start_time:end_time,loc]
        result_up_quantile = up_predictions_quantile[time_stamp,start_time:end_time,loc]

        result_gpde_quantile = averaged_predeictions_gpde_quantile[time_stamp,start_time:end_time,loc]
        result_down_gpde_quantile = down_predictions_gpde_quantile[time_stamp,start_time:end_time,loc]
        result_up_gpde_quantile = up_predictions_gpde_quantile[time_stamp,start_time:end_time,loc]

        result_gpde_quantile_phy = averaged_predeictions_gpde_quantile_phy[time_stamp,start_time:end_time,loc]
        result_down_gpde_quantile_phy = down_predictions_gpde_quantile_phy[time_stamp,start_time:end_time,loc]
        result_up_gpde_quantile_phy = up_predictions_gpde_quantile_phy[time_stamp,start_time:end_time,loc]

        result_truth = truths_quantile[time_stamp,start_time:end_time,loc]

        plt.figure(figsize=(10, 5))
        plt.plot(result_quantile, linestyle='--', color='y', marker='|', markersize=4,label="quantile model",alpha=0.8)  
        plt.plot(result_gpde_quantile, linestyle='--', color='g', marker='|', markersize=4,label="gpde quantile model",alpha=0.8)
        plt.plot(result_gpde_quantile_phy, linestyle='--', color='b', marker='|', markersize=4,label="gpde quantile phy model",alpha=0.8)
        plt.fill_between(np.arange(len(result_quantile)), result_down_quantile, result_up_quantile, color='y', alpha=0.2)
        plt.fill_between(np.arange(len(result_gpde_quantile)), result_down_gpde_quantile, result_up_gpde_quantile, color='g', alpha=0.2)
        plt.fill_between(np.arange(len(result_gpde_quantile_phy)), result_down_gpde_quantile_phy, result_up_gpde_quantile_phy, color='b', alpha=0.2)

        plt.plot(result_truth, linestyle='--', color='r', marker='|', markersize=4,label="Truth",alpha=0.8)  

        tick_positions = np.linspace(0, 576, 16, dtype=int)  
        labels = [''] * len(tick_positions)  

        

        labels[2] = (f'06/{8+i}/2012')  
        labels[10] = (f'06/{9+i}/2012')  

        plt.xticks(tick_positions, labels)

        #plt.xlabel('Hours')
        plt.ylabel('Speed:mph')
        plt.title(f'METR-LA Location {loc} Prediction')
        plt.legend()
        #plt.show()

        
        filename = f'{location_folder}/plot_{i}.png'
        plt.savefig(filename)
        plt.close()

# %%
# 15 min plot

num_days = 12 * 24 *2
start_time = 100
time_stamp = 3-1

for loc in range(207):
    location_folder = 'D:/uncertainty/EviDCRNN/plot/METR-LA/15min/Location_' + str(loc)
    if not os.path.exists(location_folder):
        os.makedirs(location_folder)
    
    for i in range(20):
        start_time = i * 24 * 12
        end_time = start_time + num_days

        result_quantile = averaged_predeictions_quantile[time_stamp,start_time:end_time,loc]
        result_down_quantile = down_predictions_quantile[time_stamp,start_time:end_time,loc]
        result_up_quantile = up_predictions_quantile[time_stamp,start_time:end_time,loc]

        result_gpde_quantile = averaged_predeictions_gpde_quantile[time_stamp,start_time:end_time,loc]
        result_down_gpde_quantile = down_predictions_gpde_quantile[time_stamp,start_time:end_time,loc]
        result_up_gpde_quantile = up_predictions_gpde_quantile[time_stamp,start_time:end_time,loc]

        result_gpde_quantile_phy = averaged_predeictions_gpde_quantile_phy[time_stamp,start_time:end_time,loc]
        result_down_gpde_quantile_phy = down_predictions_gpde_quantile_phy[time_stamp,start_time:end_time,loc]
        result_up_gpde_quantile_phy = up_predictions_gpde_quantile_phy[time_stamp,start_time:end_time,loc]

        result_truth = truths_quantile[time_stamp,start_time:end_time,loc]

        plt.figure(figsize=(10, 5))
        plt.plot(result_quantile, linestyle='--', color='y', marker='|', markersize=4,label="quantile model",alpha=0.8)  
        plt.plot(result_gpde_quantile, linestyle='--', color='g', marker='|', markersize=4,label="gpde quantile model",alpha=0.8)
        plt.plot(result_gpde_quantile_phy, linestyle='--', color='b', marker='|', markersize=4,label="gpde quantile phy model",alpha=0.8)
        plt.fill_between(np.arange(len(result_quantile)), result_down_quantile, result_up_quantile, color='y', alpha=0.2)
        plt.fill_between(np.arange(len(result_gpde_quantile)), result_down_gpde_quantile, result_up_gpde_quantile, color='g', alpha=0.2)
        plt.fill_between(np.arange(len(result_gpde_quantile_phy)), result_down_gpde_quantile_phy, result_up_gpde_quantile_phy, color='b', alpha=0.2)

        plt.plot(result_truth, linestyle='--', color='r', marker='|', markersize=4,label="Truth",alpha=0.8)  

        tick_positions = np.linspace(0, 576, 16, dtype=int)  
        labels = [''] * len(tick_positions)  

        

        labels[2] = (f'06/{8+i}/2012')  
        labels[10] = (f'06/{9+i}/2012')  


        plt.xticks(tick_positions, labels)

        #plt.xlabel('Hours')
        plt.ylabel('Speed:mph')
        plt.title(f'METR-LA Location {loc} Prediction')
        plt.legend()
        #plt.show()

     
        filename = f'{location_folder}/plot_{i}.png'
        plt.savefig(filename)
        plt.close()

# %%
# 30 min plot

num_days = 12 * 24 *2
start_time = 100
time_stamp = 6-1

for loc in range(207):
    location_folder = 'D:/uncertainty/EviDCRNN/plot/METR-LA/30min/Location_' + str(loc)
    if not os.path.exists(location_folder):
        os.makedirs(location_folder)
    
    for i in range(20):
        start_time = i * 24 * 12
        end_time = start_time + num_days

        result_quantile = averaged_predeictions_quantile[time_stamp,start_time:end_time,loc]
        result_down_quantile = down_predictions_quantile[time_stamp,start_time:end_time,loc]
        result_up_quantile = up_predictions_quantile[time_stamp,start_time:end_time,loc]

        result_gpde_quantile = averaged_predeictions_gpde_quantile[time_stamp,start_time:end_time,loc]
        result_down_gpde_quantile = down_predictions_gpde_quantile[time_stamp,start_time:end_time,loc]
        result_up_gpde_quantile = up_predictions_gpde_quantile[time_stamp,start_time:end_time,loc]

        result_gpde_quantile_phy = averaged_predeictions_gpde_quantile_phy[time_stamp,start_time:end_time,loc]
        result_down_gpde_quantile_phy = down_predictions_gpde_quantile_phy[time_stamp,start_time:end_time,loc]
        result_up_gpde_quantile_phy = up_predictions_gpde_quantile_phy[time_stamp,start_time:end_time,loc]

        result_truth = truths_quantile[time_stamp,start_time:end_time,loc]

        plt.figure(figsize=(10, 5))
        plt.plot(result_quantile, linestyle='--', color='y', marker='|', markersize=4,label="quantile model",alpha=0.8)  
        plt.plot(result_gpde_quantile, linestyle='--', color='g', marker='|', markersize=4,label="gpde quantile model",alpha=0.8)
        plt.plot(result_gpde_quantile_phy, linestyle='--', color='b', marker='|', markersize=4,label="gpde quantile phy model",alpha=0.8)
        #plt.fill_between(np.arange(len(result_quantile)), result_down_quantile, result_up_quantile, color='y', alpha=0.2)
        #plt.fill_between(np.arange(len(result_gpde_quantile)), result_down_gpde_quantile, result_up_gpde_quantile, color='g', alpha=0.2)
        #plt.fill_between(np.arange(len(result_gpde_quantile_phy)), result_down_gpde_quantile_phy, result_up_gpde_quantile_phy, color='b', alpha=0.2)

        plt.plot(result_truth, linestyle='--', color='r', marker='|', markersize=4,label="Truth",alpha=0.8)  

        tick_positions = np.linspace(0, 576, 16, dtype=int)  
        labels = [''] * len(tick_positions)  


        labels[2] = (f'06/{8+i}/2012')  
        labels[10] = (f'06/{9+i}/2012')  

        plt.xticks(tick_positions, labels)

        #plt.xlabel('Hours')
        plt.ylabel('Speed:mph')
        plt.title(f'METR-LA Location {loc} Prediction')
        plt.legend()
        #plt.show()


        filename = f'{location_folder}/plot_{i}.png'
        plt.savefig(filename)
        plt.close()

# %%
# 60 min plot

num_days = 12 * 24 *2
start_time = 100
time_stamp = 12-1

for loc in range(207):
    location_folder = 'D:/uncertainty/EviDCRNN/plot/METR-LA/60min/Location_' + str(loc)
    if not os.path.exists(location_folder):
        os.makedirs(location_folder)
    
    for i in range(20):
        start_time = i * 24 * 12
        end_time = start_time + num_days

        result_quantile = averaged_predeictions_quantile[time_stamp,start_time:end_time,loc]
        result_down_quantile = down_predictions_quantile[time_stamp,start_time:end_time,loc]
        result_up_quantile = up_predictions_quantile[time_stamp,start_time:end_time,loc]

        result_gpde_quantile = averaged_predeictions_gpde_quantile[time_stamp,start_time:end_time,loc]
        result_down_gpde_quantile = down_predictions_gpde_quantile[time_stamp,start_time:end_time,loc]
        result_up_gpde_quantile = up_predictions_gpde_quantile[time_stamp,start_time:end_time,loc]

        result_gpde_quantile_phy = averaged_predeictions_gpde_quantile_phy[time_stamp,start_time:end_time,loc]
        result_down_gpde_quantile_phy = down_predictions_gpde_quantile_phy[time_stamp,start_time:end_time,loc]
        result_up_gpde_quantile_phy = up_predictions_gpde_quantile_phy[time_stamp,start_time:end_time,loc]

        result_truth = truths_quantile[time_stamp,start_time:end_time,loc]

        plt.figure(figsize=(10, 5))
        plt.plot(result_quantile, linestyle='--', color='y', marker='|', markersize=4,label="quantile model",alpha=0.8)  
        plt.plot(result_gpde_quantile, linestyle='--', color='g', marker='|', markersize=4,label="gpde quantile model",alpha=0.8)
        plt.plot(result_gpde_quantile_phy, linestyle='--', color='b', marker='|', markersize=4,label="gpde quantile phy model",alpha=0.8)
        #plt.fill_between(np.arange(len(result_quantile)), result_down_quantile, result_up_quantile, color='y', alpha=0.2)
        #plt.fill_between(np.arange(len(result_gpde_quantile)), result_down_gpde_quantile, result_up_gpde_quantile, color='g', alpha=0.2)
        #plt.fill_between(np.arange(len(result_gpde_quantile_phy)), result_down_gpde_quantile_phy, result_up_gpde_quantile_phy, color='b', alpha=0.2)

        plt.plot(result_truth, linestyle='--', color='r', marker='|', markersize=4,label="Truth",alpha=0.8)  

        tick_positions = np.linspace(0, 576, 16, dtype=int)  
        labels = [''] * len(tick_positions)  

        

        labels[2] = (f'06/{8+i}/2012')  
        labels[10] = (f'06/{9+i}/2012') 

        plt.xticks(tick_positions, labels)

        #plt.xlabel('Hours')
        plt.ylabel('Speed:mph')
        plt.title(f'METR-LA Location {loc} Prediction')
        plt.legend()
        #plt.show()

        filename = f'{location_folder}/plot_{i}.png'
        plt.savefig(filename)
        plt.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 10
#       8 location_folder = 'D:/uncertainty/EviDCRNN/plot/METR-LA/60min/Location_' + str(loc)
#       9 if not os.path.exists(location_folder):
# ---> 10     os.makedirs(location_folder)
#      12 for i in range(20):
#      13     start_time = i * 24 * 12
#
# File ~\AppData\Local\anaconda3\Lib\os.py:215, in makedirs(name, mode, exist_ok)
#     213 if head and tail and not path.exists(head):
#     214     try:
# --> 215         makedirs(head, exist_ok=exist_ok)
#     216     except FileExistsError:
#     217         # Defeats race condition when another thread created the path
#     218         pass
#
# File ~\AppData\Local\anaconda3\Lib\os.py:215, in makedirs(name, mode, exist_ok)
#     213 if head and tail and not path.exists(head):
#     214     try:
# --> 215         makedirs(head, exist_ok=exist_ok)
# ...
